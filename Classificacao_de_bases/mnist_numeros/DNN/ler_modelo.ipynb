# %%
import load_dataset as ld

import tensorflow as tf
from tensorflow import keras
import h5py
import numpy as np
import csv
import matplotlib.pyplot as plt

# %%
x_test, y_test = ld.load_dataset("../mnist_test.csv", 28, 28)
# Out:
# c:\Users\mathe\OneDrive\Área de Trabalho\iniciacao_cientifica\Classificacao_de_bases\mnist_numeros\DNN

# %%
model = ld.load_model("model.json", "model.h5")

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy']
)

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=1) 
print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0964 - accuracy: 0.9784
# Test accuracy: 0.9783999919891357

# %%
def print_image(image):
    plt.figure()
    plt.imshow(image[0])
    plt.show
    plt.pause(0.001)

# %%
while True:
    index = int(input("Digite o index desejado: "))

    index -= 1

    image = x_test[index].reshape((1,28,28))

    print_image(image)

    prediction = model.predict(image)

    print("\nResultado encontrado: ",np.argmax(prediction))
    print("Resultado esperado: ", int(y_test[index]))
# Out:
# 1/1 [==============================] - 0s 34ms/step
#
# Resultado encontrado:  1
# Resultado esperado:  1
# 1/1 [==============================] - 0s 44ms/step
#
# Resultado encontrado:  6
# Resultado esperado:  6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 while True:
# ----> 2     index = int(input("Digite o index desejado: "))
#       4     index -= 1
#       6     image = x_test[index].reshape((1,28,28))
#
# ValueError: invalid literal for int() with base 10: ''
